# %%
import pandas as pd

# Caminho do arquivo
path = "/home/brown/Documents/macro_fred/fred/data/01_raw/fred/DFII10.parquet"

# Carregar
df = pd.read_parquet(path)

print("=== HEAD ===")
display(df.head())

print("\n=== TAIL ===")
display(df.tail())

print("\n=== SCHEMA ===")
df.info()

print("\n=== PERÍODO ===")
print("Início:", df["date"].min())
print("Fim   :", df["date"].max())
print("Total de linhas:", len(df))

print("\n=== VALORES NULOS ===")
print(df.isna().sum())

print("\n=== ESTATÍSTICAS BÁSICAS ===")
display(df["value"].describe())

print("\n=== CHECAGEM DE VALORES INVÁLIDOS ===")
invalid_mask = df["value"].isna()
print("Linhas com value NaN:", invalid_mask.sum())

print("\n=== CONTINUIDADE TEMPORAL ===")
# Diferença entre datas consecutivas
date_diff = df["date"].sort_values().diff().value_counts().head(10)
display(date_diff)

print("\n=== FREQUÊNCIA INFERIDA ===")
print(pd.infer_freq(df["date"].sort_values()))

print("\n=== AMOSTRA DE BURACOS (GAPS > 3 dias) ===")
gaps = df["date"].sort_values().diff()
display(df.loc[gaps > pd.Timedelta(days=3)].head())

# %%
import pandas as pd

# Caminho do Parquet da série DGS10
path = (
    "/Users/brown/Documents/MLGeral/crypto_v2/crypto-market-state/data/01_raw/macro/monthly/FEDFUNDS.parquet"
)

# Carregar dados
df = pd.read_parquet(path)

# Visões básicas
display(df.head())
display(df.tail())

print("Shape:", df.shape)
print("\nDtypes:")
print(df.dtypes)

print("\nIntervalo temporal:")
print("Início:", df["date"].min())
print("Fim:", df["date"].max())

print("\nValores ausentes:")
print(df.isna().sum())
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                        date        close         high          low  \
# 0 2000-01-03 00:00:00+00:00  1455.219971  1478.000000  1438.359985
# 1 2000-01-04 00:00:00+00:00  1399.420044  1455.219971  1397.430054
# 2 2000-01-05 00:00:00+00:00  1402.109985  1413.270020  1377.680054
# 3 2000-01-06 00:00:00+00:00  1403.449951  1411.900024  1392.099976
# 4 2000-01-07 00:00:00+00:00  1441.469971  1441.469971  1400.729980
#
#           open      volume
# 0  1469.250000   931800000
# 1  1455.219971  1009000000
# 2  1399.420044  1085500000
# 3  1402.109985  1092300000
# 4  1403.449951  1225200000
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                           date        close         high          low  \
# 6550 2026-01-20 00:00:00+00:00  6796.859863  6871.169922  6789.049805
# 6551 2026-01-21 00:00:00+00:00  6875.620117  6910.390137  6804.959961
# 6552 2026-01-22 00:00:00+00:00  6913.350098  6934.750000  6893.620117
# 6553 2026-01-23 00:00:00+00:00  6915.609863  6932.959961  6895.500000
# 6554 2026-01-26 00:00:00+00:00  6950.229980  6964.660156  6921.600098
#
#              open      volume
# 6550  6865.240234  5769500000
# 6551  6810.709961  5835520000
# 6552  6914.439941  5307580000
# 6553  6907.850098  4871930000
# 6554  6923.229980  4968050000
# Shape: (6555, 6)
#
# Dtypes:
# date      datetime64[ns, UTC]
# close                 float64
# high                  float64
# low                   float64
# open                  float64
# volume                  int64
# dtype: object
#
# Intervalo temporal:
# Início: 2000-01-03 00:00:00+00:00
# Fim: 2026-01-26 00:00:00+00:00
#
# Valores ausentes:
# date      0
# close     0
# high      0
# low       0
# open      0
# volume    0
# dtype: int64

# %%
import pandas as pd

# Caminho do Parquet da série DGS10
path = (
    "/Users/edmundobrown/Documents/MLGeral/AI-Finance/teste-cursor/crypto-mkt-state/data/03_primary/macro/fred/CPIAUCSL"
)

# Carregar dados
df = pd.read_parquet(path)

# Visões básicas
display(df.head())
display(df.tail())

print("Shape:", df.shape)
print("\nDtypes:")
print(df.dtypes)

print("\nIntervalo temporal:")
print("Início:", df["date"].min())
print("Fim:", df["date"].max())

print("\nValores ausentes:")
print(df.isna().sum())
# Out:
#                        date  value series_id asset   category source interval  \
# 0 2000-01-01 00:00:00+00:00  169.3  CPIAUCSL   cpi  inflation   fred       1d
# 1 2000-02-01 00:00:00+00:00  170.0  CPIAUCSL   cpi  inflation   fred       1d
# 2 2000-03-01 00:00:00+00:00  171.0  CPIAUCSL   cpi  inflation   fred       1d
# 3 2000-04-01 00:00:00+00:00  170.9  CPIAUCSL   cpi  inflation   fred       1d
# 4 2000-05-01 00:00:00+00:00  171.2  CPIAUCSL   cpi  inflation   fred       1d
#
#                       ingestion_ts  delta_1d  pct_change_1d  ...  \
# 0 2026-01-27 19:41:39.234829+00:00       NaN            NaN  ...
# 1 2026-01-27 19:41:39.234829+00:00       0.7       0.004135  ...
# 2 2026-01-27 19:41:39.234829+00:00       1.0       0.005882  ...
# 3 2026-01-27 19:41:39.234829+00:00      -0.1      -0.000585  ...
# 4 2026-01-27 19:41:39.234829+00:00       0.3       0.001755  ...
#
#    rolling_std_21  zscore_21  rolling_mean_63  rolling_std_63  zscore_63  \
# 0             NaN        NaN              NaN             NaN        NaN
# 1             NaN        NaN              NaN             NaN        NaN
# 2             NaN        NaN              NaN             NaN        NaN
# 3             NaN        NaN              NaN             NaN        NaN
# 4             NaN        NaN              NaN             NaN        NaN
#
#    rolling_mean_252  rolling_std_252  zscore_252  value_minus_mean_252  \
# 0               NaN              NaN         NaN                   NaN
# 1               NaN              NaN         NaN                   NaN
# 2               NaN              NaN         NaN                   NaN
# 3               NaN              NaN         NaN                   NaN
# 4               NaN              NaN         NaN                   NaN
#
#    percentile_rank_252
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 23 columns]
#                          date    value series_id asset   category source  \
# 307 2025-08-01 00:00:00+00:00  323.364  CPIAUCSL   cpi  inflation   fred
# 308 2025-09-01 00:00:00+00:00  324.368  CPIAUCSL   cpi  inflation   fred
# 309 2025-10-01 00:00:00+00:00      NaN  CPIAUCSL   cpi  inflation   fred
# 310 2025-11-01 00:00:00+00:00  325.031  CPIAUCSL   cpi  inflation   fred
# 311 2025-12-01 00:00:00+00:00  326.030  CPIAUCSL   cpi  inflation   fred
#
#     interval                     ingestion_ts  delta_1d  pct_change_1d  ...  \
# 307       1d 2026-01-27 19:41:39.234829+00:00     1.232       0.003825  ...
# 308       1d 2026-01-27 19:41:39.234829+00:00     1.004       0.003105  ...
# 309       1d 2026-01-27 19:41:39.234829+00:00       NaN       0.000000  ...
# 310       1d 2026-01-27 19:41:39.234829+00:00       NaN       0.002044  ...
# 311       1d 2026-01-27 19:41:39.234829+00:00     0.999       0.003074  ...
#
#      rolling_std_21  zscore_21  rolling_mean_63  rolling_std_63  zscore_63  \
# 307        4.290903   1.677547       294.734905       20.972776   1.365060
# 308        4.293357   1.737047       295.803571       20.735108   1.377588
# 309             NaN        NaN              NaN             NaN        NaN
# 310             NaN        NaN              NaN             NaN        NaN
# 311             NaN        NaN              NaN             NaN        NaN
#
#      rolling_mean_252  rolling_std_252  zscore_252  value_minus_mean_252  \
# 307         243.97631        35.072121    2.263555              79.38769
# 308         244.51031        35.267863    2.264319              79.85769
# 309               NaN              NaN         NaN                   NaN
# 310               NaN              NaN         NaN                   NaN
# 311               NaN              NaN         NaN                   NaN
#
#      percentile_rank_252
# 307             1.003984
# 308             1.003984
# 309             0.000000
# 310             1.000000
# 311             1.000000
#
# [5 rows x 23 columns]
# Shape: (312, 23)
#
# Dtypes:
# date                    datetime64[ns, UTC]
# value                               float64
# series_id                            object
# asset                                object
# category                             object
# source                               object
# interval                             object
# ingestion_ts            datetime64[us, UTC]
# delta_1d                            float64
# pct_change_1d                       float64
# delta_21d                           float64
# pct_change_21d                      float64
# rolling_mean_21                     float64
# rolling_std_21                      float64
# zscore_21                           float64
# rolling_mean_63                     float64
# rolling_std_63                      float64
# zscore_63                           float64
# rolling_mean_252                    float64
# rolling_std_252                     float64
# zscore_252                          float64
# value_minus_mean_252                float64
# percentile_rank_252                 float64
# dtype: object
#
# Intervalo temporal:
# Início: 2000-01-01 00:00:00+00:00
# Fim: 2025-12-01 00:00:00+00:00
#
# Valores ausentes:
# date                      0
# value                     1
# series_id                 0
# asset                     0
# category                  0
# source                    0
# interval                  0
# ingestion_ts              0
# delta_1d                  3
# pct_change_1d             1
# delta_21d                22
# pct_change_21d           21
# rolling_mean_21          23
# rolling_std_21           23
# zscore_21                23
# rolling_mean_63          65
# rolling_std_63           65
# zscore_63                65
# rolling_mean_252        254
# rolling_std_252         254
# zscore_252              254
# value_minus_mean_252    254
# percentile_rank_252     251
# dtype: int64
